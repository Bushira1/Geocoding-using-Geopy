# %% [markdown]
# # HOW TO GEOCODE AND MAP ADDRESSES USING Geopy

# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import folium
from folium import Marker
import warnings

# %% [markdown]
# Geocoding is the process of converting the name of a place or an address into geographic coordinates, typically latitude and longitude.
# This enables the location to be identified on a map and used in various applications and services.
# Geocoding is commonly used in navigation systems, mapping services, and geospatial analysis.
# It allows for precise positioning and spatial analysis based on the geographic data associated with a particular address or place. Geocoding is achieved by using geocoding software or APIs (Application Programming Interfaces) that access geospatial databases containing information about addresses and their corresponding coordinates.

# %%
from geopy.geocoders import Nominatim

# %% [markdown]
# Nominatim is a widely used geocoding software.
# It is an open-source and free geocoder that is developed and maintained by the OpenStreetMap (OSM) community.
# Nominatim converts addresses and place names into geographic coordinates, allowing users to search for locations and retrieve their corresponding latitude and longitude values.
# It is commonly used in various applications and services that require geocoding functionality, such as mapping platforms, location-based services, and geospatial analysis tools.
# Nominatim utilizes the data available in the OpenStreetMap database to perform geocoding operations and provides accurate and reliable results for a wide range of locations worldwide.

# %%
geolocator=Nominatim(user_agent="kdrmohammed@gmail.com")
location=geolocator.geocode("Aksum")
print(location.point)
print(location.address)
# Out:
# 14 7m 19.5535s N, 38 43m 55.8296s E
# ኣኽሱም, Central Tigray, ትግራይ, ኢትዮጵያ

# %%
point=location.point
print("Latitude:", point.latitude)
print("Longitude:", point.longitude)
# Out:
# Latitude: 14.1220982
# Longitude: 38.7321749

# %% [markdown]
# # How to geocode many different locations at once

# %%
uni=pd.read_csv("top_universities.csv")

# %%
uni.head()
# Out:
#                       Name
# 0     University of Oxford
# 1  University of Cambridge
# 2  Imperial College London
# 3               ETH Zurich
# 4                      UCL

# %% [markdown]
# To apply the geocoder to every row in a DataFrame using a lambda function, you can use the apply method provided by pandas

# %%
uni['geocode']=uni['Name'].apply(geolocator.geocode)
uni.head()
# Out:
#                       Name                                            geocode
# 0     University of Oxford  (Sherardian Library of Plant Taxonomy, South P...
# 1  University of Cambridge  (Museum of Classical Archaeology and Faculty o...
# 2  Imperial College London  (Imperial College London, Exhibition Road, Kni...
# 3               ETH Zurich  (ETH Zürich, 130, Binzmühlestrasse, Oerlikon, ...
# 4                      UCL  (UCL, 188, Tottenham Court Road, St Giles, Fit...

# %% [markdown]
# # Extract the Latitude and Longitude Coordinates

# %% [markdown]
# To retrieve the latitude and longitude information from the geocode column, we can loop through the contents and store the result in a new column.

# %%
uni['latitude']=[g.latitude for g in uni.geocode]
uni['longitude']=[g.longitude for g in uni.geocode]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 uni['latitude']=[g.latitude for g in uni.geocode]
#       2 uni['longitude']=[g.longitude for g in uni.geocode]
#
# Cell In[25], line 1, in <listcomp>(.0)
# ----> 1 uni['latitude']=[g.latitude for g in uni.geocode]
#       2 uni['longitude']=[g.longitude for g in uni.geocode]
#
# AttributeError: 'NoneType' object has no attribute 'latitude'

# %% [markdown]
# Check for null value in geocode

# %%
null=uni.isnull()

# %%
print(null)
# Out:
#      Name  geocode
# 0   False    False
# 1   False    False
# 2   False    False
# 3   False    False
# 4   False    False
# ..    ...      ...
# 95  False    False
# 96  False     True
# 97  False    False
# 98  False    False
# 99  False    False
#
# [100 rows x 2 columns]

# %% [markdown]
# Remove the null values from the DataFrame uni using the dropna() function and store the resulting DataFrame as uni1.

# %%
uni1=uni.dropna(inplace=False)

# %% [markdown]
# retrieve the latitude and longitude information from the geocode column, we can loop through the contents and store the result in a new column.
# Hope this time it works

# %%
uni1['latitude']=[g.latitude for g in uni1.geocode]
uni1['longitude']=[g.longitude for g in uni1.geocode]
# Out:
# C:\Users\kedir\AppData\Local\Temp\ipykernel_6388\371656117.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   uni1['latitude']=[g.latitude for g in uni1.geocode]
# C:\Users\kedir\AppData\Local\Temp\ipykernel_6388\371656117.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   uni1['longitude']=[g.longitude for g in uni1.geocode]

# %%
uni1.head()
# Out:
#                       Name                                            geocode
# 0     University of Oxford  (Sherardian Library of Plant Taxonomy, South P...  \
# 1  University of Cambridge  (Museum of Classical Archaeology and Faculty o...
# 2  Imperial College London  (Imperial College London, Exhibition Road, Kni...
# 3               ETH Zurich  (ETH Zürich, 130, Binzmühlestrasse, Oerlikon, ...
# 4                      UCL  (UCL, 188, Tottenham Court Road, St Giles, Fit...
#
#     latitude  longitude
# 0  51.759037  -1.252430
# 1  52.200623   0.110474
# 2  51.498959  -0.175641
# 3  47.413218   8.537491
# 4  51.521785  -0.135151

# %% [markdown]
# # Map the Addreses using Folium

# %%
unimap=folium.Map(location=[54,15], tiles='openstreetmap', zoom_start=2)
for idx, row in uni1.iterrows():
    Marker([row["latitude"], row["longitude"]], popup=row['Name']).add_to(unimap)
unimap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4db0ecc4c5bc3e984ebf690df192658d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4db0ecc4c5bc3e984ebf690df192658d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4db0ecc4c5bc3e984ebf690df192658d = L.map(
#                 &quot;map_4db0ecc4c5bc3e984ebf690df192658d&quot;,
#                 {
#                     center: [54.0, 15.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_51201cae9db17a27cb94e8d640c0527f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4db0ecc4c5bc3e984ebf690df192658d);
#
#
#             var marker_a0355ee2a2fe959be70726bc5b8c6241 = L.marker(
#                 [51.7590373, -1.2524298],
#                 {}
#             ).addTo(map_4db0ecc4c5bc3e984ebf690df192658d);
#
#
#         var popup_f0815f5525b58307b7c0c93c2dd03a2b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8474b8d47880f8bf812d4f041544a871 = $(`&lt;div id=&quot;html_8474b8d47880f8bf812d4f041544a871&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;University of Oxford&lt;/div&gt;`)[0];
#                 popup_f0815f5525b58307b7c0c93c2dd03a2b.setContent(html_8474b8d47880f8bf812d4f041544a871);
#
#
#
#         marker_a0355ee2a2fe959be70726bc5b8c6241.bindPopup(popup_f0815f5525b58307b7c0c93c2dd03a2b)
#         ;
#
#
#
#
#             var marker_23935856ce69ef1394c04cd4f4ddd9d9 = L.marker(
#                 [52.2006233, 0.1104744],
#                 {}
#             ).addTo(map_4db0ecc4c5bc3e984ebf690df192658d);
#
#
#         var popup_648145f427c927448633737439d2a287 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2f3d8943c266eb8bb5d482eeac807891 = $(`&lt;div id=&quot;html_2f3d8943c266eb8bb5d482eeac807891&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;University of Cambridge&lt;/div&gt;`)[0];
#                 popup_648145f427c927448633737439d2a287.setContent(html_2f3d8943c266eb8bb5d482eeac807891);
#
#
#
#         marker_23935856ce69ef1394c04cd4f4ddd9d9.bindPopup(popup_648145f427c927448633737439d2a287)
#         ;
#
#
#
#
#             var marker_218b3d8246b84261b9f1e4c6ea31e18a = L.marker(
#                 [51.4989595, -0.17564069276310426],
#                 {}
#             ).addTo(map_4db0ecc4c5bc3e984ebf690df192658d);
#
#
#         var popup_446ad96846024301cebef47c4a020bf2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1cad87ab8681c6d9701ad76d07253686 = $(`&lt;div id=&quot;html_1cad87ab8681c6d9701ad76d07253686&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Imperial College London&lt;/div&gt;`)[0];
#                 popup_446ad96846024301cebef47c4a020bf2.setContent(html_1cad87ab8681c6d9701ad76d07253686);
#
#
#
#         marker_218b3d8246b84261b9f1e4c6ea31e18a.bindPopup(popup_446ad96846024301cebef47c4a020bf2)
#         ;
#
#
#
#
#             var marker_681b489ad93be7b601c0c29089e21ed6 = L.marker(
#                 [47.413218, 8.5374914],
#                 {}
#             ).addTo(map_4db0ecc4c5bc3e984ebf690df192658d);
#
#
#         var popup_eabedec85e22e5395b793a255490edc4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_463a922d25611c5fc124480ababe3b4f = $(`&lt;div id=&quot;html_463a922d25611c5fc124480ababe3b4f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ETH Zurich&lt;/div&gt;`)[0];
#                 popup_eabedec85e22e5395b793a255490edc4.setContent(html_463a922d25611c5fc124480ababe3b4f);
#
#
#
#         marker_681b489ad93be7b601c0c29089e21ed6.bindPopup(popup_eabedec85e22e5395b793a255490edc4)
#         ;
#
#
#
#
#             var marker_c244aa4490d3ac6ecba3e9b124016329 = L.marker(
#                 [51.5217852, -0.13515149671251314],
#                 {}
#             ).addTo(map_4db0ecc4c5bc3e984ebf690df192658d);
#
#
#         var popup_5f26ca1f327610462a40aed41d0281cc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b61d3334efb58f8090d7941e275d0963 = $(`&lt;div id=&quot;html_b61d3334efb58f8090d7941e275d0963&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;UCL&lt;/div&gt;`)[0];
#                 popup_5f26ca1f327610462a40aed41d0281cc.setContent(html_b61d3334efb58f8090d7941e275d0963);
#
#
#
#         marker_c244aa4490d3ac6ecba3e9b124016329.bindPopup(popup_5f26ca1f327610462a40aed41d0281cc)
#         ;
#
#
#
#
#             var marker_48513bf82090f15048f957f2de219622 = L.marker(
#                 [51.514261
